# %% [markdown]
# # Actividad
#
# - **Nombre**: Miguel Monroy Hurtado
# - **Matrícula**: A01382658
#
# # Entregar
# Archivo PDF de la actividad y la liga de la actividad en su repostitorio.
#
# # Nota:
# Todas las tareas entregadas fuera de la fecha limite se califican sobre 50 de los 100 puntos posibles.

# %% [markdown]
# **Presion Arterial**

# %% [markdown]
# 1. Carga los datos del archivo **presion.csv**

# %%
# Si trabajamos en Google Colaboratory corremos las siguientes lineas de código
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Nos cambiamos a la carpeta donde tengamos el repositorio
# %cd 'drive/MyDrive/SemanaTec/Repos/arte-analitica'
# Out:
# /content/drive/MyDrive/SemanaTec/Repos/arte-analitica

# %%
# Carga las librerías y datos
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  print('Se cargó el archivo: "{name}" con una longitud de {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-97a8be34-2269-4969-aec0-255224e192d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97a8be34-2269-4969-aec0-255224e192d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving presion.csv to presion (1).csv
# Se cargó el archivo: "presion.csv" con una longitud de 97 bytes

# %% [markdown]
# 2. Gráfica la información en el eje de las x la edad  y en el eje y la presión

# %%
#Observamos la forma de la tabla a trabajar
import pandas as pd
import io

df = pd.read_csv(io.StringIO(uploaded['presion.csv'].decode('utf-8')))
df.head(3)
# Out:
#    edad  presion  Unnamed: 2
# 0    56      148         NaN
# 1    45      120         NaN
# 2    72      159         NaN

# %%
import numpy as np
import pandas as pd
# Matplotlib lo utilizamos con el acrónimo plt
import matplotlib.pyplot as plt
# Seaborn lo utilizamos con el acrónimo sns
import seaborn as sns

# Para hacer las gráficas más bonitas cambiamos el estilo a Seaborn
sns.set()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

# %%
# Primero vamos a cargar el dataset con el que vamos a trabajar.
presion_df = pd.read_csv('presion.csv')

#Creamos una gráfica de dispersion
fig = plt.figure(figsize=(8, 6))
sns.scatterplot(data= presion_df, x = 'edad', y = 'presion')
plt.title('Relación Edad - Presion Arterial')
# Out:
# Text(0.5, 1.0, 'Relación Edad - Presion Arterial')

# %% [markdown]
# 3. Genera una regresión líneal para obtener una aproximación de la ecuación
# $$
# y = ax + b
# $$
# donde $ a $ se conoce comúnmente como * pendiente *, y $ b $ se conoce comúnmente como * intersección *.
#
# ¿Cuál es el valor de a y cuál es el valor de b?

# %%
datos = presion_df.iloc[:, 0:2]
datos.head()
# Out:
#    edad  presion
# 0    56      148
# 1    45      120
# 2    72      159
# 3    36      118
# 4    63      146

# %%
x = datose = datos.iloc[:,0:1]
datose.head()
# Out:
#    edad
# 0    56
# 1    45
# 2    72
# 3    36
# 4    63

# %%
y = datosp = datos.iloc[:,1:2]
datosp.head()
# Out:
#    presion
# 0      148
# 1      120
# 2      159
# 3      118
# 4      146

# %%
# Vamos a verificar el modelo.
x = datos['edad']
y = datos['presion']
# Calcular los promedios
x_bar = np.mean(x)
y_bar = np.mean(y)
# Los coeficientes
beta_1 = np.sum((x-x_bar)*(y-y_bar))/np.sum((x-x_bar)**2)
beta_0 = y_bar - beta_1*x_bar

print('beta_0: {:.3f}'.format(beta_0))
print('beta_1: {:.3f}'.format(beta_1))

#Donde Beta 0 es el valor de la intersección, mientras que Beta 1 es el valor de la pendiente
# Out:
# beta_0: 79.369
# beta_1: 1.148

# %%
sns.regplot(data= datos, x='edad',y='presion', color='blue')
plt.title('Regresión Lineal Generada Automáticamente')
# Out:
# Text(0.5, 1.0, 'Regresión Lineal Generada Automáticamente')

# %% [markdown]
# 4. Gráfica los datos reales vs modelo obtenido.
#
# Se debe visualizar los datos reales ( azules)
# Recta del modelo ( negra)
# Distancias ( verde )

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)
x = datose
y = datosp

model.fit(x, y)


xfit = np.linspace(0,80,1000)
yfit = model.predict(xfit)

plt.scatter(x, y)
plt.plot(xfit, yfit, color="green");
plt.plot(x,y, 'o')
plt.plot(np.vstack([x,x]), np.vstack([y, model.predict(x)]), color="red");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-32eea03b383a> in <module>()
#       8
#       9 xfit = np.linspace(0,80,1000)
# ---> 10 yfit = model.predict(xfit)
#      11
#      12 plt.scatter(x, y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     205         check_is_fitted(self)
#     206
# --> 207         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     208         return safe_sparse_dot(X, self.coef_.T,
#     209                                dense_output=True) + self.intercept_
#
# ...

# %%
x
# Out:
#    edad
# 0    56
# 1    45
# 2    72
# 3    36
# 4    63
# 5    47
# 6    55
# 7    47
# 8    38
# 9    42

# %%
#Primero graficamos el modelo manual
y_modelo = beta_0 + beta_1*x
sns.scatterplot(data= datos, x='edad', y='presion', color='blue')
# Aquí como tenemos varias gráficas, vamos a cambiar por axs en vez de plt.
axs[0].plot(x, y_modelo, color='darkblue')
# Como estamos usando los axes, cambia un poco la función para el título
axs[0].set_title('Regresión lineal manual')

# %% [markdown]
# 4. ¿Cuál es la presión arterial esperada para una persona de 76 años?
#
# Genera una función que calcule lo anterior

# %%
edad_calcular= 76

def presion(e):
  z = 79.369 + 1.148*e
  return (z)
presion(edad_calcular)
# Out:
# 166.617

# %% [markdown]
# **Ventas de mi negocio**
#
# Nuestro objetivo será contruir un modelo que prediga las ventas del producto dependiendo de cuánto presupuesto se gaste en cada medio.

# %% [markdown]
# 1. Carga los datos del archivo AdvmiNegocio.csv

# %%
# Carga las librerías y datos
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  print('Se cargó el archivo: "{name}" con una longitud de {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-d1b617ff-392e-4963-a65d-e5cf7ab36a3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1b617ff-392e-4963-a65d-e5cf7ab36a3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AdvmiNegocio.csv to AdvmiNegocio.csv
# Se cargó el archivo: "AdvmiNegocio.csv" con una longitud de 4199 bytes

# %% [markdown]
# 2. Generar una grafica para visuaizar  cómo se relaciona cada columna de presupuesto contra las ventas. De mi negocio. ( Redes,Youtube,TV)

# %%
df = pd.read_csv(io.StringIO(uploaded['AdvmiNegocio.csv'].decode('utf-8')))
df.head(3)
# Out:
#    Unnamed: 0  Redes  Youtube    TV  sales
# 0           1   6903     1134  2076    663
# 1           2   1335     1179  1353    312
# 2           3    516     1377  2079    279

# %%
datos_minegocio = df.iloc[:, 0:5]
datos_minegocio.head()
# Out:
#    Unnamed: 0  Redes  Youtube    TV  sales
# 0           1   6903     1134  2076    663
# 1           2   1335     1179  1353    312
# 2           3    516     1377  2079    279
# 3           4   4545     1239  1755    555
# 4           5   5424      324  1752    387

# %%
datos_redes = datos_minegocio.iloc[:,1:2]
datos_redes.head()
# Out:
#    Redes
# 0   6903
# 1   1335
# 2    516
# 3   4545
# 4   5424

# %%
datos_yt = datos_minegocio.iloc[:,2:3]
datos_yt.head()
# Out:
#    Youtube
# 0     1134
# 1     1179
# 2     1377
# 3     1239
# 4      324

# %%
datos_tv = datos_minegocio.iloc[:,3:4]
datos_tv.head()
# Out:
#      TV
# 0  2076
# 1  1353
# 2  2079
# 3  1755
# 4  1752

# %%
datos_sales = datos_minegocio.iloc[:,4:5]
datos_sales.head()
# Out:
#    sales
# 0    663
# 1    312
# 2    279
# 3    555
# 4    387

# %%
#Creamos una gráfica de dispersion
fig = plt.figure(figsize=(8, 6))
sns.scatterplot(data= df, x = 'Redes', y = 'sales')
plt.title('Ventas debido a promoción en Redes')
# Out:
# Text(0.5, 1.0, 'Ventas debido a promoción en Redes')

# %%
#Creamos una gráfica de dispersion
fig = plt.figure(figsize=(8, 6))
sns.scatterplot(data= df, x = 'TV', y = 'sales')
plt.title('Ventas debido a promoción en TV')
# Out:
# Text(0.5, 1.0, 'Ventas debido a promoción en TV')

# %%
#Creamos una gráfica de dispersion
fig = plt.figure(figsize=(8, 6))
sns.scatterplot(data= df, x = 'Youtube', y = 'sales')
plt.title('Ventas debido a promoción en Youtube')
# Out:
# Text(0.5, 1.0, 'Ventas debido a promoción en Youtube')

# %% [markdown]
# 3. ¿ Qué conclusiones puedes obtener de las graficas anteriores?

# %% [markdown]
# El crecimiento que podemos observar más claro es el de las redes sociales, donde a mayor dinero incrementa tambien el número de ventas. Esta es la opción más viable para invertir en publicidad. En la gráfica de Youtube aunque tambien podemos observar un crecimiento, puede ser un poco más disperso y no se asegura que la inversión vaya a tener buenos resultados, mientras que en la TV los resultados son aún más dispersos.

# %% [markdown]
# 4. **Regresión lineal**. En su forma más simple, consiste en asumir que una variable $x$ y una variable $y$ presentan una relación lineal de la forma:
#
# $$ y \approx \beta_0 + \beta_1 \cdot x$$
#
# ¿Cuál es el valor de beta_0 , beta_1 y el Score  para Redes vs Ventas, TV vs Ventas y YouTube vs Ventas?

# %%
# Televisión
lm1 = LinearRegression()
# La variable X la ponemos con doble corchete!
lm1.fit(datos_minegocio[['TV']], datos_minegocio['sales'])
print('TV')
print('beta_0: ', lm1.intercept_)
print('beta_1: ', lm1.coef_)
print('Score: ', lm1.score(datos_minegocio[['TV']], datos_minegocio['sales']), '\n')

# Youtube
lm2 = LinearRegression()
# La variable X la ponemos con doble corchete!
lm2.fit(datos_minegocio[['Youtube']], datos_minegocio['sales'])
print('Youtube')
print('beta_0: ', lm2.intercept_)
print('beta_1: ', lm2.coef_)
print('Score: ', lm2.score(datos_minegocio[['Youtube']], datos_minegocio['sales']), '\n')


# Redes
lm3 = LinearRegression()
# La variable X la ponemos con doble corchete!
lm3.fit(datos_minegocio[['Redes']], datos_minegocio['sales'])
print('Redes')
print('beta_0: ', lm3.intercept_)
print('beta_1: ', lm3.coef_)
print('Score: ', lm3.score(datos_minegocio[['Redes']], datos_minegocio['sales']))
# Out:
# TV
# beta_0:  370.5422120783448
# beta_1:  [0.0546931]
# Score:  0.05212044544430494
#
# Youtube
# beta_0:  279.3491428547485
# beta_1:  [0.20249578]
# Score:  0.33203245544529536
#
# Redes
# beta_0:  210.97780647383084
# beta_1:  [0.04753664]
# Score:  0.611875050850071

# %% [markdown]
# 5. ¿Cuál de los modelos es mejor de acuerdo al score ordenalos del mejor al peor?

# %% [markdown]
# ##Mejor a Peor
# 1. Redes
# 2. Youtube
# 3. TV

# %% [markdown]
# 6.  **Regresión lineal múltiple**. Como ahora vamos a incluir más de una variable, el modelo se rescribe a :
#
# $$ \hat{y} = \hat{\beta}_0 + \hat{\beta}_1 \cdot x_1 + \hat{\beta}_2 \cdot x_2 + \hat{\beta}_3\cdot x_3 + \ldots \epsilon $$
#
# Elige  las diferentes combinaciones de variables. Ejemplo: Redes y Youtube vs Ventas
#
# ¿Cuál es el valor de beta_0, betas_1 , beta_2 , el score y el score ajustado?

# %%
def score_adj(X, y, model):
    return 1 - (1-model.score(X, y))*(len(y)-1)/(len(y)-X.shape[1]-1)

# %%
# Vamos a calcular el modelo con dos variables simultáneas
# Televisión y Redes
lm4 = LinearRegression()
# La variable X la ponemos con doble corchete!
lm4.fit(datos_minegocio[['TV', 'Redes']], datos_minegocio['sales'])
print('TV y Redes')
print('beta_0: ', lm4.intercept_)
print('betas: ', lm4.coef_)
print('Score: ', lm4.score(datos_minegocio[['TV', 'Redes']], datos_minegocio['sales']),)
print('Score ajustado:', score_adj(datos_minegocio[['TV', 'Redes']],
                                   datos_minegocio['sales'], lm4), '\n')

# Tv y Youtube
lm5 = LinearRegression()
# La variable X la ponemos con doble corchete!
lm5.fit(datos_minegocio[['TV','Youtube']], datos_minegocio['sales'])
print('TV y Youtube')
print('beta_0: ', lm5.intercept_)
print('betas: ', lm5.coef_)
print('Score: ', lm5.score(datos_minegocio[['TV','Youtube']], datos_minegocio['sales']),)
print('Score ajustado:', score_adj(datos_minegocio[['TV', 'Youtube']],
                                   datos_minegocio['sales'], lm4), '\n')


# Redes y Youtube
lm6 = LinearRegression()
# La variable X la ponemos con doble corchete!
lm6.fit(datos_minegocio[['Redes','Youtube']], datos_minegocio['sales'])
print('Redes y Youtube')
print('beta_0: ', lm6.intercept_)
print('betas: ', lm6.coef_)
print('Score: ', lm6.score(datos_minegocio[['Redes','Youtube']], datos_minegocio['sales']))
print('Score ajustado:', score_adj(datos_minegocio[['Redes', 'Youtube']],
                                   datos_minegocio['sales'], lm4), '\n')
# Out:
# TV y Redes
# beta_0:  173.24843903734907
# betas:  [0.04421942 0.04690121]
# Score:  0.6458354938293271
# Score ajustado: 0.6422399150864777
#
# TV y Youtube
# beta_0:  275.6676137758969
# betas:  [0.00664417 0.19904459]
# Score:  0.33270518395032256
# Score ajustado: -1.0965919342095987
#
# Redes y Youtube
# beta_0:  87.63299737215414
# betas:  [0.04575482 0.18799423]
# Score:  0.8971942610828956
# Score ajustado: 0.7155815036185544

# %% [markdown]
# 7.  ¿Cuál modelo es el que nos conviene elegir?

# %% [markdown]
# El mejor modelo, o el que más se ajusta es el de Redes y Youtube, ya que el score ajustado (esto quiere decir que tanto se acercan nuestros valores a los datos reales) es de 0.71.
