# %% [markdown]
# # Actividad
#
# - **Nombre**: Miguel Monroy Hurtado
# - **Matrícula**: A01382658
#
# # Entregar
# Archivo PDF de la actividad y la liga de la actividad en su repostitorio.
#
# # Nota:
# Todas las tareas entregadas fuera de la fecha limite se califican sobre 50 de los 100 puntos posibles.

# %%
# Si trabajamos en Google Colaboratory corremos las siguientes lineas de código
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Nos cambiamos a la carpeta donde tengamos el repositorio. Si es otra carpeta asegúrate de cambiar la ruta.
# %cd 'drive/MyDrive/SemanaTec/Repos/arte-analitica'
# Out:
# /content/drive/MyDrive/SemanaTec/Repos/arte-analitica

# %% [markdown]
# # Iris dataset
#
# Este famoso conjunto de datos corresopnde a un análisis multivariado que el biólogo Ronald Fisher utilizó en su artículo de 1936 *The use of multiple measurements in taxonomic problems* para ejemplificar un análisis discriminante lineal.
#
# Los datos consisten en 4 mediciones para tres especies de flor Iris (Iris setosa, Iris virginica and Iris versicolor). Las 4 mediciones corresponden a la longitud y altura de los sépalos y de los pétalos de cada especimen.
#
# ![iris2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Actividad
# Carga el dataset  `iris.csv` de la carpeta de datos y haz un análisis estadístico de las variables.

# %%
import numpy as np
import pandas as pd

# %%
# Carga los datos y muestra los primeros renglones
# Importar los datos
iris_df = pd.read_csv('data/iris.csv')

# %%
#Imprimir primeros datos.
iris_df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Crea una tabla resumen con los estadísticos generales de las variables numéricas
iris_df.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# ¿Cuántas observaciones hay de cada tipo de flor?
iris_df['Species'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: Species, dtype: int64

# %%
# ¿Cómo se comparan los pétalos y sépalos para las distintas especies de flor?
# Calcula los estadísticos de tendencia central y dispersión para cada especie.
iris_df.groupby('Species').mean()['Sepal.Width']
# Out:
# Species
# setosa        3.428
# versicolor    2.770
# virginica     2.974
# Name: Sepal.Width, dtype: float64

# %%
iris_df.groupby('Species').mean()['Sepal.Length']
# Out:
# Species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: Sepal.Length, dtype: float64

# %%
iris_df.groupby('Species').mean()['Petal.Length']
# Out:
# Species
# setosa        1.462
# versicolor    4.260
# virginica     5.552
# Name: Petal.Length, dtype: float64

# %%
iris_df.groupby('Species').mean()['Petal.Width']
# Out:
# Species
# setosa        0.246
# versicolor    1.326
# virginica     2.026
# Name: Petal.Width, dtype: float64

# %%
iris_df.groupby('Species').std(ddof=1)['Sepal.Width']
# Out:
# Species
# setosa        0.379064
# versicolor    0.313798
# virginica     0.322497
# Name: Sepal.Width, dtype: float64

# %%
iris_df.groupby('Species').std(ddof=1)['Sepal.Length']
# Out:
# Species
# setosa        0.352490
# versicolor    0.516171
# virginica     0.635880
# Name: Sepal.Length, dtype: float64

# %%
iris_df.groupby('Species').std(ddof=1)['Petal.Width']
# Out:
# Species
# setosa        0.105386
# versicolor    0.197753
# virginica     0.274650
# Name: Petal.Width, dtype: float64

# %%
iris_df.groupby('Species').std(ddof=1)['Petal.Length']
# Out:
# Species
# setosa        0.173664
# versicolor    0.469911
# virginica     0.551895
# Name: Petal.Length, dtype: float64

# %%
iris_df.groupby('Species').var(ddof=1)['Sepal.Width']
# Out:
# Species
# setosa        0.143690
# versicolor    0.098469
# virginica     0.104004
# Name: Sepal.Width, dtype: float64

# %%
iris_df.groupby('Species').var(ddof=1)['Sepal.Length']
# Out:
# Species
# setosa        0.124249
# versicolor    0.266433
# virginica     0.404343
# Name: Sepal.Length, dtype: float64

# %%
iris_df.groupby('Species').var(ddof=1)['Petal.Width']
# Out:
# Species
# setosa        0.011106
# versicolor    0.039106
# virginica     0.075433
# Name: Petal.Width, dtype: float64

# %%
iris_df.groupby('Species').var(ddof=1)['Petal.Length']
# Out:
# Species
# setosa        0.030159
# versicolor    0.220816
# virginica     0.304588
# Name: Petal.Length, dtype: float64

# %%
# Importar lass librerías de visualización y manejo de datos

import numpy as np
import pandas as pd
# Matplotlib lo utilizamos con el acrónimo plt
import matplotlib.pyplot as plt
# Seaborn lo utilizamos con el acrónimo sns
import seaborn as sns

# Para hacer las gráficas más bonitas cambiamos el estilo a Seaborn
sns.set()

# %%
# ¿Qué relación hay entre las 4 variables? Obtén la matriz de correlación y escribe tus conclusiones.
# Vamos a obtener la matriz de correlación de las tres variables (ingreso, población y esperanza de vida)
corr_matrix = iris_df.loc[:, ['Sepal.Length','Sepal.Width','Petal.Length','Petal.Width']].corr()

# El resultado siempre es una matriz cuadrada con el número de columnas igual al número de variables.
corr_matrix
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length      0.871754    -0.428440      1.000000     0.962865
# Petal.Width       0.817941    -0.366126      0.962865     1.000000

# %%
# Vamos a graficar la matriz con un mapa de calor
# Con el parámetro cmap podemos cambiar el mapa de colores.

sns.heatmap(data=corr_matrix, vmin=-1, vmax=1, cmap='RdBu')
